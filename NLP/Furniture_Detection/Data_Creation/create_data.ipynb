# %%
import pandas as pd
import numpy as np

# %%
import os
with open("example_sentences.txt", encoding='utf-8') as f:
            lines = f.readlines()

# %%
EXAMPLE_SENTENCES = lines

# %%
import os
with open("furniture.txt", encoding='utf-8') as f:
            lines = f.readlines()

# %%
lines
# Out:
# ['Desk\n',
#  'Sofa\n',
#  'Telephone\n',
#  'Television\n',
#  'Speaker\n',
#  'End table\n',
#  'Tea set\n',
#  'Fireplace\n',
#  'Remote\n',
#  'Fan\n',
#  'Floor lamp\n',
#  'Carpet\n',
#  'Table\n',
#  'Blinds\n',
#  'Curtains\n',
#  'Picture\n',
#  'Vase\n',
#  'vanity mirror\n',
#  'Grandfather clock\n',
#  'Writing desk\n',
#  'Bedside table\n',
#  'Card table\n',
#  'Conference table\n',
#  'Computer desk\n',
#  'Work table\n',
#  'End table\n',
#  'Dining room table\n',
#  'Dressing table\n',
#  'Patio table\n',
#  'Bar table\n',
#  'Picnic table\n',
#  'tennis table\n',
#  'Bin\n',
#  'Trash\n',
#  'Trash box\n',
#  'Baby bottle\n',
#  'Bassinet\n',
#  'Bib\n',
#  'Doll\n',
#  'Rattle\n',
#  'Diaper\n',
#  'Pacifier\n',
#  'Dummy\n',
#  'Mobile\n',
#  'Puzzle\n',
#  'Doll’s house\n',
#  'umbrella stand \n',
#  'Cot\n',
#  'Crib\n',
#  'Toy chest\n',
#  'coat rock\n',
#  'Safety pin\n',
#  'Stroller \n',
#  'Pram\n',
#  'Teddy bear\n',
#  'Block\n',
#  'Park bench\n',
#  'Upholstered bench\n',
#  'Armchair\n',
#  'Cantilever chair\n',
#  'Wing chair\n',
#  'Deck chair\n',
#  'Desk chair\n',
#  'Barber chair\n',
#  'Salon chair\n',
#  'Operator chair\n',
#  'Executive chair\n',
#  'Garden chair\n',
#  'Director’s chair\n',
#  'Chair\n',
#  'Folding chair\n',
#  'Throne\n',
#  'Ladderback chair\n',
#  'Stool\n',
#  'Windsor chair\n',
#  'Wheelchair\n',
#  'Waiting room seat\n',
#  'Wooden outdoor chair\n',
#  'Adirondack chair\n',
#  'Student chair\n',
#  'Dining room chair\n',
#  'Wood chair\n',
#  'Air-conditioner\n',
#  'Clothes valet\n',
#  'Bed\n',
#  'Anglepoise lamp\n',
#  'Balanced-arm lamp\n',
#  'Upholstered bench\n',
#  'Bedside table\n',
#  'Bookshelf\n',
#  'Bureau\n',
#  'Desk\n',
#  'Chest of drawers\n',
#  'Dresser\n',
#  'Clock\n',
#  'Fan\n',
#  'Pillow\n',
#  'Hat stand\n',
#  'Dressing table\n',
#  'Table lamp\n',
#  'Desk lamp\n',
#  'Mirror\n',
#  'Curtains\n',
#  'Ironing board\n',
#  'Hope chest\n',
#  'Picture\n',
#  'Nightstand\n',
#  'Wing chair\n',
#  'TV stand\n',
#  'Sofa\n',
#  'Cushion\n']

# %%
furnitures = []
labels = []
furniture_id = []
id = 0 
for line in lines:
    array_of_line = line.split()
    length = len(array_of_line)
    furnitures.append(array_of_line[0])
    labels.append("B-FUR")
    furniture_id.append(id)
    if length > 1:
                for k in range(1,length):
                                        furnitures.append(array_of_line[k])
                                        labels.append("I-FUR")
                                        furniture_id.append(id)
    id = id+1

# %%
furniture_data = pd.DataFrame({
    "f_id":furniture_id,
    "word":furnitures,
    "label":labels
})
furniture_data
# Out:
#      f_id        word  label
# 0       0        Desk  B-FUR
# 1       1        Sofa  B-FUR
# 2       2   Telephone  B-FUR
# 3       3  Television  B-FUR
# 4       4     Speaker  B-FUR
# ..    ...         ...    ...
# 172   107       chair  I-FUR
# 173   108          TV  B-FUR
# 174   108       stand  I-FUR
# 175   109        Sofa  B-FUR
# 176   110     Cushion  B-FUR
#
# [177 rows x 3 columns]

# %%
sentence_id = []
labels = []
words = []

# %%
liste = [1,4,2,3,7]
liste.index(4)
# Out:
# 1

# %%
import os
with open("additional_furniture.txt", encoding='utf-8') as f:
            lines = f.readlines()

# %%
additional_furnitures = []
for i in range(len(lines)):
        x = lines[i]
        x = x[:-1]
        additional_furnitures.append(x)

additional_furnitures
# Out:
# ['storage container',
#  'television',
#  'sound system',
#  'computer',
#  'bed',
#  'glasses',
#  'glass',
#  'billiard table',
#  'blankets',
#  'blanket',
#  'linens',
#  'linen',
#  'umbrellas',
#  'umbrella',
#  'book',
#  'books',
#  'novels',
#  'novel',
#  'chairs',
#  'mirror',
#  'shelves',
#  'cushions',
#  'desk',
#  'cabin',
#  'chaise',
#  'recliner',
#  'seat',
#  'tray',
#  'tablet',
#  'pillow',
#  'TV',
#  'mirror',
#  'wheels',
#  '']

# %%
with open("material.txt", encoding='utf-8') as f:
            lines = f.readlines()

materials = []
for i in range(len(lines)):
        x = lines[i]
        x = x[:-1]
        materials.append(x)

materials
# Out:
# ['glass', 'leather', 'wooden', 'marble', 'metal', 'wicker', 'linen']

# %%
with open("shape.txt", encoding='utf-8') as f:
            lines = f.readlines()

shapes = []
for i in range(len(lines)):
        x = lines[i]
        x = x[:-1]
        shapes.append(x)

shapes
# Out:
# ['broad',
#  'chubby',
#  'crooked',
#  'round',
#  'low',
#  'square',
#  'wide',
#  'triangle',
#  'sleek',
#  'tall',
#  'small',
#  'hexagonal']

# %%
with open("color.txt", encoding='utf-8') as f:
            lines = f.readlines()

colors = []
for i in range(len(lines)):
        x = lines[i]
        x = x[:-1]
        colors.append(x)

colors
# Out:
# ['White',
#  'Yellow',
#  'Blue',
#  'Red',
#  'Green',
#  'Black',
#  'Brown',
#  'Azure',
#  'Ivory',
#  'Teal',
#  'Silver',
#  'Purple',
#  'Gray',
#  'Orange',
#  'Maroon',
#  'Charcoal',
#  'Aquamarine',
#  'Coral',
#  'Fuchsia',
#  'Wheat',
#  'Lime',
#  'Crimson',
#  'Khaki',
#  'pink',
#  'Magenta',
#  'Olden',
#  'Plum',
#  'Olive',
#  'Cyan']

# %% [markdown]
# import random
# def func_create_data(furniture_id, example_sentence_remain, id):
#     if len(example_sentence_remain)<20:
#         example_sentence_remain = EXAMPLE_SENTENCES.copy()
#
#     lst = list(range(0,len(example_sentence_remain)))
#     random_samples = random.sample(lst,20)
#
#     sample_sentence = example_sentence_remain.copy()
#
#     print(random_samples)
#     for t in range(20):
#        #print(random_samples[t])
#        to_be_deleted_sentence = example_sentence_remain[random_samples[t]]
#        to_be_deleted_index = sample_sentence.index(to_be_deleted_sentence)
#        del sample_sentence[to_be_deleted_index]
#
#
#     for i in range(20):
#         tnk = 0
#         sntnc = example_sentence_remain[random_samples[i]]
#         list_of_words = sntnc.split()
#         syst_bool = 0
#         if any(item in sntnc for item in additional_furnitures):
#             if ('storage container' in sntnc) or ('sound system' in sntnc) or ('billiard table' in sntnc):
#                 for t in range(len(list_of_words)):
#                     k = list_of_words[t]
#                     if syst_bool == 1:
#                         syst_bool = 0
#                         continue
#                     if k == "[MASK]":
#                         f_data = furniture_data[furniture_data["f_id"]==furniture_id]
#                         for j in range(len(f_data)):
#                             labels.append(f_data.label.iloc[j])
#                             sentence_id.append(id)
#                             words.append(f_data.word.iloc[j])
#
#                     elif (k == "storage") or (k == "billiard") or (k =="sound"):
#                         labels.append("B-FUR")
#                         sentence_id.append(id)
#                         words.append(k)
#                         labels.append("I-FUR")
#                         sentence_id.append(id)
#                         words.append(list_of_words[t+1])
#                         syst_bool = 1
#
#                     else:
#                         labels.append("O")
#                         sentence_id.append(id)
#                         words.append(k)
#             else:
#                 for t in range(len(list_of_words)):
#                     k = list_of_words[t]
#                     if k == "[MASK]":
#                         f_data = furniture_data[furniture_data["f_id"]==furniture_id]
#                         for j in range(len(f_data)):
#                             labels.append(f_data.label.iloc[j])
#                             sentence_id.append(id)
#                             words.append(f_data.word.iloc[j])
#
#                     elif k in additional_furnitures:
#                         labels.append("B-FUR")
#                         sentence_id.append(id)
#                         words.append(k)
#
#                     elif (("." in k)or ("?" in k)) and (t == len(list_of_words)-1):
#                         tmp = k[:-1]
#                         tmp2 = k[-1]
#
#                         if tmp in additional_furnitures:
#                             labels.append("B-FUR")
#                             sentence_id.append(id)
#                             words.append(tmp)
#                         else:
#                             labels.append("O")
#                             sentence_id.append(id)
#                             words.append(tmp)
#
#                         labels.append("O")
#                         sentence_id.append(id)
#                         words.append(tmp2)
#
#                     else:
#                         labels.append("O")
#                         sentence_id.append(id)
#                         words.append(k)
#
#         else:
#
#             for t in range(len(list_of_words)):
#                 k = list_of_words[t]
#                 if k == "[MASK]":
#                     f_data = furniture_data[furniture_data["f_id"]==furniture_id]
#                     for j in range(len(f_data)):
#                         labels.append(f_data.label.iloc[j])
#                         sentence_id.append(id)
#                         words.append(f_data.word.iloc[j])
#                 elif( ("." in k) or ('?' in k) )and (t == len(list_of_words)-1):
#                     tmp = k[:-1]
#                     tmp2 = k[-1]
#                     labels.append("O")
#                     labels.append("O")
#                     sentence_id.append(id)
#                     sentence_id.append(id)
#                     words.append(tmp)
#                     words.append(tmp2)
#
#
#                 else:
#                     labels.append("O")
#                     sentence_id.append(id)
#                     words.append(k)
#         id+=1
#     return sample_sentence,id

# %%
import random
s = random.choice(shapes)
s
# Out:
# 'square'

# %%
import random
def func_create_data(furniture_id, example_sentence_remain, id):
    if len(example_sentence_remain)<30:
        example_sentence_remain = EXAMPLE_SENTENCES.copy()
    
    lst = list(range(0,len(example_sentence_remain)))
    random_samples = random.sample(lst,30)

    sample_sentence = example_sentence_remain.copy()

    print(random_samples)
    for t in range(30):
       #print(random_samples[t])
       to_be_deleted_sentence = example_sentence_remain[random_samples[t]]
       to_be_deleted_index = sample_sentence.index(to_be_deleted_sentence)
       del sample_sentence[to_be_deleted_index]

    
    for i in range(30):
        tnk = 0
        sntnc = example_sentence_remain[random_samples[i]]
        list_of_words = sntnc.split()
        
        if any(item in sntnc for item in additional_furnitures):
            if ('storage container' in sntnc) or ('sound system' in sntnc) or ('billiard table' in sntnc):
                syst_bool = 0 #for additional furnitures
                begin = 0
                for t in range(len(list_of_words)):
                    k = list_of_words[t]

                    if syst_bool == 1:
                        syst_bool = 0
                        continue
                    #[SHAPE] [COLOR] [MATERIAL] [MASK]
                    if k == "[SHAPE]":
                        if begin == 0:
                            begin = 1
                            labels.append("B-FUR")
                        else:
                            labels.append("I-FUR")

                        s = random.choice(shapes)
                        sentence_id.append(id)
                        words.append(s)
                    
                    elif k == "[COLOR]":
                        if begin == 0:
                            begin = 1
                            labels.append("B-FUR")
                        else:
                            labels.append("I-FUR")

                        s = random.choice(colors)
                        sentence_id.append(id)
                        words.append(s)

                    elif k == "[MATERIAL]":
                        if begin == 0:
                            begin = 1
                            labels.append("B-FUR")
                        else:
                            labels.append("I-FUR")

                        s = random.choice(materials)
                        sentence_id.append(id)
                        words.append(s)
                        

                    elif k == "[MASK]":
                        f_data = furniture_data[furniture_data["f_id"]==furniture_id]
                        if begin == 0:
                            for j in range(len(f_data)):
                                labels.append(f_data.label.iloc[j])
                                sentence_id.append(id)
                                words.append(f_data.word.iloc[j])
                            begin = 1
                        else:
                            for j in range(len(f_data)):
                                labels.append("I-FUR")
                                sentence_id.append(id)
                                words.append(f_data.word.iloc[j])


                    elif (k == "storage") or (k == "billiard") or (k =="sound"):
                        labels.append("B-FUR")
                        sentence_id.append(id)
                        words.append(k)
                        labels.append("I-FUR")
                        sentence_id.append(id)
                        words.append(list_of_words[t+1])
                        t+=1
                        syst_bool = 1

                    elif k in additional_furnitures:
                        labels.append("B-FUR")
                        sentence_id.append(id)
                        words.append(k)
                    else:
                        labels.append("O")
                        sentence_id.append(id)
                        words.append(k)
            else:# additional furniture var ve tek kelimeden olusuyor
                begin = 0
                #syst_bool = 0 #begining of additional firnuture
                for t in range(len(list_of_words)):
                    k = list_of_words[t]

                    if k == "[SHAPE]":
                        if begin == 0:
                            begin = 1
                            labels.append("B-FUR")
                        else:
                            labels.append("I-FUR")

                        s = random.choice(shapes)
                        sentence_id.append(id)
                        words.append(s)
                    
                    elif k == "[COLOR]":
                        if begin == 0:
                            begin = 1
                            labels.append("B-FUR")
                        else:
                            labels.append("I-FUR")

                        s = random.choice(colors)
                        sentence_id.append(id)
                        words.append(s)

                    elif k == "[MATERIAL]":
                        if begin == 0:
                            begin = 1
                            labels.append("B-FUR")
                        else:
                            labels.append("I-FUR")

                        s = random.choice(materials)
                        sentence_id.append(id)
                        words.append(s)

                    elif k == "[MASK]":
                        if begin == 0:
                            begin = 1
                            f_data = furniture_data[furniture_data["f_id"]==furniture_id]
                            for j in range(len(f_data)):
                                labels.append(f_data.label.iloc[j])
                                sentence_id.append(id)
                                words.append(f_data.word.iloc[j])
                        else:
                            f_data = furniture_data[furniture_data["f_id"]==furniture_id]
                            for j in range(len(f_data)):
                                labels.append("I-FUR")
                                sentence_id.append(id)
                                words.append(f_data.word.iloc[j])

                    elif k in additional_furnitures:
                        labels.append("B-FUR")
                        sentence_id.append(id)
                        words.append(k)
                        
                    elif (("." in k)or ("?" in k)) and (t == len(list_of_words)-1):
                        tmp = k[:-1]
                        tmp2 = k[-1]

                        if tmp in additional_furnitures:
                            labels.append("B-FUR")
                            sentence_id.append(id)
                            words.append(tmp)

                        else:
                            labels.append("O")
                            sentence_id.append(id)
                            words.append(tmp)

                        labels.append("O")
                        sentence_id.append(id)
                        words.append(tmp2)

                    else:
                        labels.append("O")
                        sentence_id.append(id)
                        words.append(k)

        else: #additional furntiure ICERMIYOR
            begin = 0
            for t in range(len(list_of_words)):
                k = list_of_words[t]
                if k == "[SHAPE]":
                    if begin == 0:
                        begin = 1
                        labels.append("B-FUR")
                    else:
                         labels.append("I-FUR")

                    s = random.choice(shapes)
                    sentence_id.append(id)
                    words.append(s)
                    
                elif k == "[COLOR]":
                    if begin == 0:
                        begin = 1
                        labels.append("B-FUR")
                    else:
                        labels.append("I-FUR")

                    s = random.choice(colors)
                    sentence_id.append(id)
                    words.append(s)

                elif k == "[MATERIAL]":
                    if begin == 0:
                        begin = 1
                        labels.append("B-FUR")
                    else:
                        labels.append("I-FUR")

                    s = random.choice(materials)
                    sentence_id.append(id)
                    words.append(s)                

                elif k == "[MASK]":
                    if begin == 0:
                        begin = 1
                        f_data = furniture_data[furniture_data["f_id"]==furniture_id]
                        for j in range(len(f_data)):
                            labels.append(f_data.label.iloc[j])
                            sentence_id.append(id)
                            words.append(f_data.word.iloc[j])
                    else:
                        f_data = furniture_data[furniture_data["f_id"]==furniture_id]
                        for j in range(len(f_data)):
                            labels.append("I-FUR")
                            sentence_id.append(id)
                            words.append(f_data.word.iloc[j])

                elif( ("." in k) or ('?' in k) )and (t == len(list_of_words)-1):
                    tmp = k[:-1]
                    tmp2 = k[-1]
                    labels.append("O")
                    labels.append("O")
                    sentence_id.append(id)
                    sentence_id.append(id)
                    words.append(tmp)
                    words.append(tmp2)


                else:
                    labels.append("O")
                    sentence_id.append(id)
                    words.append(k)
        id+=1 
    return sample_sentence,id

# %%
furniture_id_list = list(range(furniture_data.f_id.max()+1))
example_sentence_remain = EXAMPLE_SENTENCES.copy()
id = 0

# %%
for i in range(furniture_data.f_id.max()+1):
    example_sentence_remain,id = func_create_data(i,example_sentence_remain,id)
# Out:
# [58, 50, 119, 15, 3, 95, 38, 98, 85, 34, 125, 19, 74, 111, 94, 24, 14, 0, 137, 100, 18, 122, 62, 27, 21, 72, 2, 33, 7, 92]
# [34, 24, 18, 72, 37, 91, 89, 55, 51, 74, 39, 16, 103, 35, 54, 99, 38, 105, 65, 88, 92, 45, 46, 95, 44, 50, 22, 79, 1, 78]
# [39, 5, 0, 50, 56, 21, 36, 76, 52, 68, 15, 53, 24, 30, 32, 44, 70, 72, 4, 46, 66, 75, 63, 49, 12, 23, 37, 3, 35, 69]
# [43, 36, 31, 30, 17, 5, 2, 19, 10, 1, 15, 40, 44, 46, 23, 20, 14, 4, 42, 24, 47, 25, 45, 41, 27, 11, 8, 28, 32, 26]
# [85, 63, 29, 141, 216, 208, 44, 106, 127, 39, 257, 128, 115, 215, 239, 46, 0, 150, 91, 226, 81, 147, 255, 173, 119, 144, 199, 191, 108, 6]
# [31, 150, 115, 139, 101, 33, 204, 59, 166, 55, 27, 74, 137, 169, 216, 80, 210, 2, 209, 148, 30, 195, 219, 29, 203, 45, 84, 38, 225, 72]
# [63, 105, 32, 135, 34, 61, 152, 50, 83, 188, 4, 98, 138, 71, 158, 74, 24, 84, 64, 149, 35, 123, 162, 154, 141, 111, 72, 16, 178, 79]
# [3, 88, 129, 145, 27, 122, 60, 76, 65, 127, 156, 101, 41, 126, 38, 0, 43, 16, 107, 109, 121, 135, 62, 67, 148, 47, 46, 39, 91, 30]
# [54, 25, 16, 55, 135, 67, 129, 57, 120, 8, 131, 115, 12, 97, 46, 38, 11, 79, 136, 10, 65, 32, 14, 26, 63, 78, 68, 122, 48, 19]
# [74, 66, 53, 9, 81, 72, 19, 32, 77, 39, 34, 76, 60, 90, 71, 33, 84, 22, 8, 48, 70, 75, 25, 105, 26, 38, 91, 16, 15, 17]
# [24, 68, 65, 12, 37, 25, 72, 50, 59, 17, 46, 71, 40, 52, 51, 8, 41, 0, 66, 39, 28, 22, 47, 61, 53, 63, 15, 62, 54, 34]

# %%
id
# Out:
# 3330

# %%
data = pd.DataFrame({
    "sentence_id":sentence_id,
    "word": words,
    "label":labels
})
data
# Out:
#        sentence_id    word  label
# 0                0       I      O
# 1                0    want      O
# 2                0       a      O
# 3                0    Plum  B-FUR
# 4                0   round  I-FUR
# ...            ...     ...    ...
# 53410         3329      to      O
# 53411         3329     the      O
# 53412         3329  living      O
# 53413         3329    room      O
# 53414         3329       .      O
#
# [53415 rows x 3 columns]

# %%
data[data["sentence_id"]==2140]
# Out:
#        sentence_id         word  label
# 34239         2140          The      O
# 34240         2140     computer  B-FUR
# 34241         2140      leather  B-FUR
# 34242         2140        Olden  I-FUR
# 34243         2140    hexagonal  I-FUR
# 34244         2140       Throne  I-FUR
# 34245         2140           in      O
# 34246         2140          the      O
# 34247         2140       office      O
# 34248         2140           is      O
# 34249         2140         very      O
# 34250         2140  comfortable      O
# 34251         2140            .      O

# %%
data.to_csv("new_data_updated_on_01_04.csv", encoding="utf-8", index=False)
